# %%
import numpy as np
import pandas as pd

# %%
test = pd.read_csv('Z:/test.csv')

# %%
test.head()
# Out:
#                                                 text sentiment
# 0                @VirginAmerica What @dhepburn said.   neutral
# 1  @VirginAmerica plus you've added commercials t...  positive
# 2  @VirginAmerica I didn't today... Must mean I n...   neutral
# 3  @VirginAmerica it's really aggressive to blast...  negative
# 4  @VirginAmerica and it's a really big bad thing...  negative

# %%
array = test['text']

# %%
data = ["negative"]

# %%
df = pd.DataFrame()

# %%
df = df.append({"text":"None"},ignore_index=True)

# %%
df = df.append({"text":"stuff"},ignore_index=True)

# %%
df
# Out:
#     text
# 0   None
# 1  stuff

# %%
array
# Out:
# 0                    @VirginAmerica What @dhepburn said.
# 1      @VirginAmerica plus you've added commercials t...
# 2      @VirginAmerica I didn't today... Must mean I n...
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
# 5                        I ❤️ flying @VirginAmerica. ☺️👍
# 6      @VirginAmerica you know what would be amazingl...
# 7      @VirginAmerica why are your first fares in May...
# 8      @VirginAmerica I love this graphic. http://t.c...
# 9      @VirginAmerica I love the hipster innovation. ...
# 10     @VirginAmerica will you be making BOS&gt;LAS n...
# 11     @VirginAmerica you guys messed up my seating.....
# 12     @VirginAmerica status match program.  I applie...
# 13     @VirginAmerica What happened 2 ur vegan food o...
# 14     @VirginAmerica do you miss me? Don't worry we'...
# 15     @VirginAmerica amazing to me that we can't get...
# ...

# %%
results = []

# %%
import requests
for i in array:
    r = requests.post(
    "https://api.deepai.org/api/sentiment-analysis",
    data={
        'text': i,
    },
    headers={'api-key': 'd89376e9-8a85-475f-b06d-54367291664f'}
      
)
    results.append(r.json())

# %%
results
# Out:
# [{'output': ['Neutral']},
#  {'output': ['Negative']},
#  {'output': ['Negative']},
#  {'output': ['Negative']},
#  {'output': ['Negative']},
#  {'output': ['Neutral', 'Neutral']},
#  {'output': ['Negative', 'Neutral', 'Positive']},
#  {'output': ['Negative']},
#  {'output': ['Positive', 'Neutral']},
#  {'output': ['Positive', 'Positive']},
#  {'output': ['Negative']},
#  {'output': ['Negative', 'Neutral', 'Negative']},
#  {'output': ['Positive', 'Neutral', 'Negative']},
#  {'output': ['Neutral', 'Negative']},
#  {'output': ['Neutral', 'Neutral']},
#  {'output': ['Positive', 'Negative']},
#  {'output': ['Positive', 'Neutral', 'Neutral']},
#  {'output': ['Positive', 'Positive', 'Negative']},
#  {'output': ['Negative']},
#  {'output': ['Negative', 'Neutral', 'Negative']},
#  {'output': ['Negative']},
#  {'output': ['Verypositive', 'Neutral']},
#  {'output': ['Positive', 'Neutral']},
#  {'output': ['Negative', 'Positive', 'Positive', 'Neutral']},
# ...

# %%
df.append(results)
# Out:
#                                                output
# 0                                           [Neutral]
# 1                                          [Negative]
# 2                                          [Negative]
# 3                                          [Negative]
# 4                                          [Negative]
# 5                                  [Neutral, Neutral]
# 6                       [Negative, Neutral, Positive]
# 7                                          [Negative]
# 8                                 [Positive, Neutral]
# 9                                [Positive, Positive]
# 10                                         [Negative]
# 11                      [Negative, Neutral, Negative]
# 12                      [Positive, Neutral, Negative]
# 13                                [Neutral, Negative]
# 14                                 [Neutral, Neutral]
# 15                               [Positive, Negative]
# ...

# %%
test.head()
# Out:
#                                                 text sentiment
# 0                @VirginAmerica What @dhepburn said.   neutral
# 1  @VirginAmerica plus you've added commercials t...  positive
# 2  @VirginAmerica I didn't today... Must mean I n...   neutral
# 3  @VirginAmerica it's really aggressive to blast...  negative
# 4  @VirginAmerica and it's a really big bad thing...  negative
